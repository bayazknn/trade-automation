# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.insert(0, '..')

# %%
import pandas as pd
from crypto_analysis import DualCNNMetaheuristicOptimizer

# %%
# Load data
df_binary = pd.read_csv('doge.csv')
df_technical = pd.read_csv('doge_ti.csv')

# %%
# Create optimizer
optimizer = DualCNNMetaheuristicOptimizer(
    df_binary, df_technical,
    pop_size=5,
    iterations=5,
    epochs_per_eval=100,
    n_workers=5,
)

# Run optimization
result = optimizer.optimize()

# Save artifacts
paths = optimizer.save_artifacts(result, output_dir='output/')
# Out:
# DualCNNMetaheuristicOptimizer (APO) initialized:
#   - Binary features: 119
#   - Technical features: 81
#   - Hyperparameters: 20
#   - Total dimension: 220
#   - Population size: 5
#   - Iterations: 5
#   - Workers: 5
#
# ============================================================
# Starting Dual-CNN LSTM APO Optimization
# Run ID: f7d54a4a
# ============================================================
#
# Evaluating initial population...
#   Individual 0 failed: DualModelConfig.__init__() got an unexpected keyword argument 'fusion_hidden_size'. Did you mean 'lstm_hidden_size'?
# iter:-1 indv:0 fitness:invalid
#   Individual 2 failed: DualModelConfig.__init__() got an unexpected keyword argument 'fusion_hidden_size'. Did you mean 'lstm_hidden_size'?
#   Individual 4 failed: DualModelConfig.__init__() got an unexpected keyword argument 'fusion_hidden_size'. Did you mean 'lstm_hidden_size'?
#   Individual 3 failed: DualModelConfig.__init__() got an unexpected keyword argument 'fusion_hidden_size'. Did you mean 'lstm_hidden_size'?
#   Individual 1 failed: DualModelConfig.__init__() got an unexpected keyword argument 'fusion_hidden_size'. Did you mean 'lstm_hidden_size'?
# iter:-1 indv:2 fitness:invalid
# iter:-1 indv:1 fitness:invalid
# iter:-1 indv:3 fitness:invalid
# iter:-1 indv:4 fitness:invalid
#
# --- Iteration 1/5 ---
# Current best fitness: -inf
# Evaluating new candidates...
# iter:0 indv:1 error: cannot convert float NaN to integer
# iter:0 indv:0 error: cannot convert float NaN to integer
# iter:0 indv:2 error: cannot convert float NaN to integer
# iter:0 indv:4 error: cannot convert float NaN to integer
#   Individual 3 failed: DualModelConfig.__init__() got an unexpected keyword argument 'fusion_hidden_size'. Did you mean 'lstm_hidden_size'?
# iter:0 indv:3 fitness:invalid
#
# --- Iteration 2/5 ---
# Current best fitness: -inf
# Evaluating new candidates...
# iter:1 indv:1 error: cannot convert float NaN to integer
# iter:1 indv:4 error: cannot convert float NaN to integer
# iter:1 indv:3 error: cannot convert float NaN to integer
# iter:1 indv:0 error: cannot convert float NaN to integer
#   Individual 2 failed: DualModelConfig.__init__() got an unexpected keyword argument 'fusion_hidden_size'. Did you mean 'lstm_hidden_size'?
# iter:1 indv:2 fitness:invalid
#
# --- Iteration 3/5 ---
# Current best fitness: -inf
# Evaluating new candidates...
# iter:2 indv:0 error: cannot convert float NaN to integer
# iter:2 indv:1 error: cannot convert float NaN to integer
# iter:2 indv:2 error: cannot convert float NaN to integer
# iter:2 indv:4 error: cannot convert float NaN to integer
#   Individual 3 failed: DualModelConfig.__init__() got an unexpected keyword argument 'fusion_hidden_size'. Did you mean 'lstm_hidden_size'?
# iter:2 indv:3 fitness:invalid
#
# --- Iteration 4/5 ---
# Current best fitness: -inf
# Evaluating new candidates...
# iter:3 indv:4 error: cannot convert float NaN to integer
# iter:3 indv:1 error: cannot convert float NaN to integer
# iter:3 indv:3 error: cannot convert float NaN to integer
# iter:3 indv:0 error: cannot convert float NaN to integer
#   Individual 2 failed: DualModelConfig.__init__() got an unexpected keyword argument 'fusion_hidden_size'. Did you mean 'lstm_hidden_size'?
# iter:3 indv:2 fitness:invalid
#
# --- Iteration 5/5 ---
# Current best fitness: -inf
# Evaluating new candidates...
# iter:4 indv:0 error: cannot convert float NaN to integer
# iter:4 indv:2 error: cannot convert float NaN to integer
# iter:4 indv:1 error: cannot convert float NaN to integer
# iter:4 indv:4 error: cannot convert float NaN to integer
#   Individual 3 failed: DualModelConfig.__init__() got an unexpected keyword argument 'fusion_hidden_size'. Did you mean 'lstm_hidden_size'?
# iter:4 indv:3 fitness:invalid
# Checkpoint saved to dual_cnn_checkpoints\checkpoint_iter_5.pkl
#
# ============================================================
# Optimization Complete (Dual-CNN LSTM)
# ============================================================
# Best fitness: -inf
# Binary features: 0
# Technical features: 0
# Best parameters: {'cnn1_kernel_size': 7, 'cnn1_num_channels': 93, 'cnn1_num_layers': 2, 'cnn2_kernel_size': 9, 'cnn2_num_channels': 118, 'cnn2_num_layers': 2, 'fusion_hidden_size': 226, 'fusion_dropout': np.float64(0.14425480724013973), 'lstm_hidden_size': 168, 'lstm_num_layers': 3, 'lstm_dropout': np.float64(0.12189932313423486), 'classifier_hidden_size': 52, 'classifier_dropout': np.float64(0.05256255942101875), 'learning_rate': np.float64(0.0007795127596090532), 'batch_size': 33, 'weight_decay': np.float64(0.004270900115465828), 'focal_gamma': np.float64(2.4687774334624457), 'label_smoothing': np.float64(0.06839502016547597), 'input_seq_length': 20, 'scheduler_patience': 8}
# c:\Users\irisbridge\Desktop\projects\freqtrade\user_data\notebooks\..\crypto_analysis\dual_cnn_optimizer.py:851: RuntimeWarning: invalid value encountered in scalar divide
#   self.fitness_pop[imk] /
# c:\Users\irisbridge\Desktop\projects\freqtrade\user_data\notebooks\..\crypto_analysis\dual_cnn_optimizer.py:822: RuntimeWarning: invalid value encountered in scalar divide
#   self.fitness_pop[km] /
# c:\Users\irisbridge\Desktop\projects\freqtrade\user_data\notebooks\..\crypto_analysis\dual_cnn_optimizer.py:851: RuntimeWarning: invalid value encountered in scalar divide
#   self.fitness_pop[imk] /
# c:\Users\irisbridge\Desktop\projects\freqtrade\user_data\notebooks\..\crypto_analysis\dual_cnn_optimizer.py:822: RuntimeWarning: invalid value encountered in scalar divide
#   self.fitness_pop[km] /
# c:\Users\irisbridge\Desktop\projects\freqtrade\user_data\notebooks\..\crypto_analysis\dual_cnn_optimizer.py:851: RuntimeWarning: invalid value encountered in scalar divide
#   self.fitness_pop[imk] /
# c:\Users\irisbridge\Desktop\projects\freqtrade\user_data\notebooks\..\crypto_analysis\dual_cnn_optimizer.py:822: RuntimeWarning: invalid value encountered in scalar divide
#   self.fitness_pop[km] /
# c:\Users\irisbridge\Desktop\projects\freqtrade\user_data\notebooks\..\crypto_analysis\dual_cnn_optimizer.py:851: RuntimeWarning: invalid value encountered in scalar divide
#   self.fitness_pop[imk] /
# c:\Users\irisbridge\Desktop\projects\freqtrade\user_data\notebooks\..\crypto_analysis\dual_cnn_optimizer.py:851: RuntimeWarning: invalid value encountered in scalar divide
#   self.fitness_pop[imk] /
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 14
#      11 result = optimizer.optimize()
#      13 # Save artifacts
# ---> 14 paths = optimizer.save_artifacts(result, output_dir='output/')
#
# File c:\Users\irisbridge\Desktop\projects\freqtrade\user_data\notebooks\..\crypto_analysis\dual_cnn_optimizer.py:955, in DualCNNMetaheuristicOptimizer.save_artifacts(self, result, output_dir)
#     952 output_path.mkdir(parents=True, exist_ok=True)
#     954 # Set seed for reproducibility
# --> 955 set_seed(result.seed)
#     957 params = result.best_params
#     958 selected_binary = result.selected_binary_features
#
# File c:\Users\irisbridge\Desktop\projects\freqtrade\user_data\notebooks\..\crypto_analysis\dual_cnn_optimizer.py:37, in set_seed(seed)
#      35 def set_seed(seed: int) -> None:
#      36     """Set random seed for reproducibility across all libraries."""
# ---> 37     random.seed(seed)
#      38     np.random.seed(seed)
#      39     torch.manual_seed(seed)
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\random.py:170, in Random.seed(self, a, version)
#     167     a = int.from_bytes(a + _sha512(a).digest())
#     169 elif not isinstance(a, (type(None), int, float, str, bytes, bytearray)):
# --> 170     raise TypeError('The only supported seed types are:\n'
#     171                     'None, int, float, str, bytes, and bytearray.')
#     173 super().seed(a)
#     174 self.gauss_next = None
#
# TypeError: The only supported seed types are:
# None, int, float, str, bytes, and bytearray.

# %%
# Load predictor and make predictions
from crypto_analysis import DualCNNPredictor
predictor = DualCNNPredictor.from_checkpoint('output/')
predictions = predictor.predict(df_binary, df_technical)
